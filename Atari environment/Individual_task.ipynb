# %%
# !pip install gymnasium[atari] autorom[accept-rom-license]
# Out:
# Collecting gymnasium[atari]
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 8.0 MB/s eta 0:00:00
# Collecting autorom[accept-rom-license]
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[atari]) (4.11.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium[atari])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting shimmy[atari]<1.0,>=0.1.0 (from gymnasium[atari])
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 12.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ale-py~=0.8.1 (from shimmy[atari]<1.0,>=0.1.0->gymnasium[atari])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 17.1 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]) (2024.2.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]<1.0,>=0.1.0->gymnasium[atari]) (6.4.0)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446659 sha256=089b06db9ca263e54f15d1592d9b5e02a7b7f75d0ce7de7c2e0ed56b6bd18706
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-0.2.1

# %%
# !pip install ray[rllib]==2.21.0 gputil
# Out:
# Collecting ray[rllib]==2.21.0
#   Downloading ray-2.21.0-cp310-cp310-manylinux2014_x86_64.whl (65.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 MB 10.8 MB/s eta 0:00:00
# Collecting gputil
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (8.1.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (3.14.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (1.0.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (24.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (3.20.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (6.0.1)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (1.3.1)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (2.0.3)
# Collecting tensorboardX>=1.9 (from ray[rllib]==2.21.0)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (14.0.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (2023.6.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (0.1.8)
# Collecting gymnasium==0.28.1 (from ray[rllib]==2.21.0)
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 46.2 MB/s eta 0:00:00
# Collecting lz4 (from ray[rllib]==2.21.0)
#   Downloading lz4-4.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.5 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (1.11.4)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (0.9.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from ray[rllib]==2.21.0) (13.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]==2.21.0) (1.25.2)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->ray[rllib]==2.21.0)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]==2.21.0) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]==2.21.0) (4.11.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->ray[rllib]==2.21.0) (0.0.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]==2.21.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]==2.21.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]==2.21.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[rllib]==2.21.0) (0.18.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]==2.21.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]==2.21.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->ray[rllib]==2.21.0) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]==2.21.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]==2.21.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]==2.21.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[rllib]==2.21.0) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[rllib]==2.21.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->ray[rllib]==2.21.0) (2.16.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]==2.21.0) (3.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]==2.21.0) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]==2.21.0) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]==2.21.0) (2024.5.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->ray[rllib]==2.21.0) (1.6.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->ray[rllib]==2.21.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->ray[rllib]==2.21.0) (1.16.0)
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=5bcc5a95af47b9d318ff48bfe104f3e166eebec84df5f34157652df473c4a0bb
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built gputil
# Installing collected packages: gputil, tensorboardX, lz4, jax-jumpy, gymnasium, ray
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 0.29.1
#     Uninstalling gymnasium-0.29.1:
#       Successfully uninstalled gymnasium-0.29.1
# Successfully installed gputil-1.4.0 gymnasium-0.28.1 jax-jumpy-1.0.0 lz4-4.3.3 ray-2.21.0 tensorboardX-2.6.2.2

# %%
import ray.rllib.algorithms.dqn as dqn
from ray import tune

config = dqn.DQNConfig()

# Rainbow DQN Parameters
config["dueling"] = True
config["double_q"] = True
config["noisy"] = True
config["n_step"] = 3
config["v_min"] = -10.0
config["v_max"] = 10.0
config["sigma0"] = 0.5
config["num_atoms"] = 51

# https://docs.ray.io/en/latest/_modules/ray/rllib/utils/replay_buffers/prioritized_replay_buffer.html
replay_config = {
                "type": "MultiAgentPrioritizedReplayBuffer",
                "capacity": 30000,
                "prioritized_replay_alpha": 0.5,
                "prioritized_replay_beta": 0.5,
                "prioritized_replay_eps": 3e-6,
                "replay_sequence_length" : 1
            }

config["replay_buffer_config"] = replay_config
config["gamma"] = 0.99
config["train_batch_size"] = 64
config["timesteps_per_iteration"] = 1000
config["target_network_update_freq"] = 800
config["num_gpus"] = 1 # Change to number of gpus (could be 0)
config["model"] = {"fcnet_hiddens": [128, 128, 128], "fcnet_activation": "relu"}
config["env"] = "FrostbiteDeterministic-v4"
config["framework"] = "torch"

analysis = tune.run("DQN", name = "FrostbiteModel", stop = {"timesteps_total": 350000}, checkpoint_freq = 20, config = config)
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if (distutils.version.LooseVersion(tf.__version__) <
# /usr/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
# 2024-05-10 21:12:20,679	INFO worker.py:1749 -- Started a local Ray instance.
# 2024-05-10 21:12:22,042	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# /usr/local/lib/python3.10/dist-packages/ray/tune/tune.py:673: DeprecationWarning: checkpoint_freq is deprecated and will be removed. use checkpoint_config.checkpoint_frequency instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:164: UserWarning: WARN: The obs returned by the `reset()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:188: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# +--------------------------------------------------------+
# | Configuration for experiment     FrostbiteModel        |
# +--------------------------------------------------------+
# | Search algorithm                 BasicVariantGenerator |
# | Scheduler                        FIFOScheduler         |
# | Number of trials                 1                     |
# +--------------------------------------------------------+
#
# View detailed results here: /root/ray_results/FrostbiteModel
# To visualize your results with TensorBoard, run: `tensorboard --logdir /tmp/ray/session_2024-05-10_21-12-16_497680_340/artifacts/2024-05-10_21-12-22/FrostbiteModel/driver_artifacts`
#
# Trial status: 1 PENDING
# Current time: 2024-05-10 21:12:22. Total running time: 0s
# Logical resource usage: 0/2 CPUs, 0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------+
# | Trial name                                  status   |
# +------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   PENDING  |
# +------------------------------------------------------+
# (pid=1015) /usr/local/lib/python3.10/dist-packages/tensorflow_probability/python/__init__.py:57: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
# (pid=1015)   if (distutils.version.LooseVersion(tf.__version__) <
# (DQN pid=1015) 2024-05-10 21:12:29,354	WARNING deprecation.py:50 -- DeprecationWarning: `WorkerSet(num_workers=... OR local_worker=...)` has been deprecated. Use `EnvRunnerGroup(num_env_runners=... AND local_env_runner=...)` instead. This will raise an error in the future!
# (DQN pid=1015) 2024-05-10 21:12:29,354	WARNING deprecation.py:50 -- DeprecationWarning: `max_num_worker_restarts` has been deprecated. Use `AlgorithmConfig.max_num_env_runner_restarts` instead. This will raise an error in the future!
# (DQN pid=1015) A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# (DQN pid=1015) [Powered by Stella]
# (DQN pid=1015) /usr/local/lib/python3.10/dist-packages/ray/rllib/models/catalog.py:895: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (DQN pid=1015)   prep = cls(observation_space, options)
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 started with configuration:
# +---------------------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 config                          |
# +---------------------------------------------------------------------------------+
# | _AlgorithmConfig__prior_exploration_config                                      |
# | _disable_action_flattening                                                False |
# | _disable_execution_plan_api                                                  -1 |
# | _disable_initialize_loss_from_dummy_batch                                 False |
# | _disable_preprocessor_api                                                 False |
# | _enable_rl_module_api                                                        -1 |
# | _env_to_module_connector                                                        |
# | _evaluation_parallel_to_training_wo_thread                                False |
# | _fake_gpus                                                                False |
# | _is_atari                                                                       |
# | _learner_class                                                                  |
# | _learner_connector                                                              |
# | _module_to_env_connector                                                        |
# | _rl_module_spec                                                                 |
# | _run_training_always_in_thread                                            False |
# | _tf_policy_handles_more_than_one_loss                                     False |
# | action_mask_key                                                     action_mask |
# | action_space                                                                    |
# | actions_in_input_normalized                                               False |
# | adam_epsilon                                                                 0. |
# | add_default_connectors_to_env_to_module_pipeline                           True |
# | add_default_connectors_to_learner_pipeline                                 True |
# | add_default_connectors_to_module_to_env_pipeline                           True |
# | always_attach_evaluation_results                                           True |
# | auto_wrap_old_gym_envs                                                       -1 |
# | batch_mode                                                    truncate_episodes |
# | before_learn_on_batch                                                           |
# | callbacks                                                  ...efaultCallbacks'> |
# | categorical_distribution_temperature                                         1. |
# | checkpoint_trainable_policies_only                                        False |
# | clip_actions                                                              False |
# | clip_rewards                                                                    |
# | compress_observations                                                     False |
# | count_steps_by                                                        env_steps |
# | create_env_on_driver                                                      False |
# | custom_async_evaluation_function                                             -1 |
# | custom_eval_function                                                            |
# | delay_between_env_runner_restarts_s                                         60. |
# | disable_env_checking                                                         -1 |
# | double_q                                                                   True |
# | dueling                                                                    True |
# | eager_max_retraces                                                           20 |
# | eager_tracing                                                              True |
# | enable_async_evaluation                                                      -1 |
# | enable_connectors                                                          True |
# | enable_env_runner_and_connector_v2                                        False |
# | enable_rl_module_and_learner                                              False |
# | enable_tf1_exec_eagerly                                                   False |
# | env                                                        ...eDeterministic-v4 |
# | env_runner_cls                                                                  |
# | env_runner_health_probe_timeout_s                                            30 |
# | env_runner_restore_timeout_s                                               1800 |
# | env_task_fn                                                                     |
# | episode_lookback_horizon                                                      1 |
# | epsilon                                                    ...), (10000, 0.05)] |
# | evaluation_config/explore                                                 False |
# | evaluation_duration                                                          10 |
# | evaluation_duration_unit                                               episodes |
# | evaluation_force_reset_envs_before_iteration                               True |
# | evaluation_interval                                                             |
# | evaluation_num_env_runners                                                    0 |
# | evaluation_parallel_to_training                                           False |
# | evaluation_sample_timeout_s                                                120. |
# | exploration_config/epsilon_timesteps                                      10000 |
# | exploration_config/final_epsilon                                           0.02 |
# | exploration_config/initial_epsilon                                          1.0 |
# | exploration_config/type                                           EpsilonGreedy |
# | explore                                                                    True |
# | export_native_model_files                                                 False |
# | fake_sampler                                                              False |
# | framework                                                                 torch |
# | gamma                                                                      0.99 |
# | grad_clip                                                                   40. |
# | grad_clip_by                                                        global_norm |
# | hiddens                                                                   [256] |
# | ignore_env_runner_failures                                                False |
# | in_evaluation                                                             False |
# | input                                                                   sampler |
# | keep_per_episode_custom_metrics                                           False |
# | local_gpu_idx                                                                 0 |
# | local_tf_session_args/inter_op_parallelism_threads                            8 |
# | local_tf_session_args/intra_op_parallelism_threads                            8 |
# | log_level                                                                  WARN |
# | log_sys_usage                                                              True |
# | logger_config                                                                   |
# | logger_creator                                                                  |
# | lr                                                                       0.0005 |
# | lr_schedule                                                                     |
# | max_num_env_runner_restarts                                                1000 |
# | max_requests_in_flight_per_sampler_worker                                     2 |
# | metrics_episode_collection_timeout_s                                        60. |
# | metrics_num_episodes_for_smoothing                                          100 |
# | min_sample_timesteps_per_iteration                                         1000 |
# | min_time_s_per_iteration                                                        |
# | min_train_timesteps_per_iteration                                             0 |
# | model/fcnet_activation                                                     relu |
# | model/fcnet_hiddens                                             [128, 128, 128] |
# | n_step                                                                        3 |
# | noisy                                                                      True |
# | normalize_actions                                                          True |
# | num_atoms                                                                    51 |
# | num_consecutive_env_runner_failures_tolerance                               100 |
# | num_cpus_for_driver                                                           1 |
# | num_cpus_per_learner_worker                                                   1 |
# | num_cpus_per_worker                                                           1 |
# | num_envs_per_env_runner                                                       1 |
# | num_gpus                                                                      1 |
# | num_gpus_per_learner_worker                                                   0 |
# | num_gpus_per_worker                                                           0 |
# | num_learner_workers                                                           0 |
# | num_steps_sampled_before_learning_starts                                   1000 |
# | num_workers                                                                   0 |
# | observation_filter                                                     NoFilter |
# | observation_fn                                                                  |
# | observation_space                                                               |
# | offline_sampling                                                          False |
# | ope_split_batch_by_episode                                                 True |
# | output                                                                          |
# | output_compress_columns                                      ['obs', 'new_obs'] |
# | output_max_file_size                                                   67108864 |
# | placement_strategy                                                         PACK |
# | policies/default_policy                                    ...None, None, None) |
# | policies_to_train                                                               |
# | policy_map_cache                                                             -1 |
# | policy_map_capacity                                                         100 |
# | policy_mapping_fn                                          ...t 0x78041ead8430> |
# | policy_states_are_swappable                                               False |
# | postprocess_inputs                                                        False |
# | preprocessor_pref                                                      deepmind |
# | recreate_failed_env_runners                                               False |
# | remote_env_batch_wait_ms                                                      0 |
# | remote_worker_envs                                                        False |
# | render_env                                                                False |
# | replay_buffer_config/capacity                                             30000 |
# | replay_buffer_config/prioritized_replay_alpha                               0.5 |
# | replay_buffer_config/prioritized_replay_beta                                0.5 |
# | replay_buffer_config/prioritized_replay_eps                               3e-06 |
# | replay_buffer_config/replay_sequence_length                                   1 |
# | replay_buffer_config/type                                  ...tizedReplayBuffer |
# | replay_sequence_length                                                          |
# | restart_failed_sub_environments                                           False |
# | rollout_fragment_length                                                    auto |
# | sample_collector                                           ...leListCollector'> |
# | sample_timeout_s                                                            60. |
# | sampler_perf_stats_ema_coef                                                     |
# | seed                                                                            |
# | shuffle_buffer_size                                                           0 |
# | sigma0                                                                      0.5 |
# | simple_optimizer                                                             -1 |
# | store_buffer_in_checkpoints                                               False |
# | sync_filters_on_rollout_workers_timeout_s                                   10. |
# | synchronize_filters                                                          -1 |
# | target_network_update_freq                                                  800 |
# | tau                                                                          1. |
# | td_error_loss_fn                                                          huber |
# | tf_session_args/allow_soft_placement                                       True |
# | tf_session_args/device_count/CPU                                              1 |
# | tf_session_args/gpu_options/allow_growth                                   True |
# | tf_session_args/inter_op_parallelism_threads                                  2 |
# | tf_session_args/intra_op_parallelism_threads                                  2 |
# | tf_session_args/log_device_placement                                      False |
# | timesteps_per_iteration                                                    1000 |
# | torch_compile_learner                                                     False |
# | torch_compile_learner_dynamo_backend                                   inductor |
# | torch_compile_learner_dynamo_mode                                               |
# | torch_compile_learner_what_to_compile                      ...ile.FORWARD_TRAIN |
# | torch_compile_worker                                                      False |
# | torch_compile_worker_dynamo_backend                                      onnxrt |
# | torch_compile_worker_dynamo_mode                                                |
# | train_batch_size                                                             64 |
# | train_batch_size_per_learner                                                    |
# | training_intensity                                                              |
# | update_worker_filter_stats                                                 True |
# | use_worker_filter_stats                                                    True |
# | v_max                                                                       10. |
# | v_min                                                                      -10. |
# | validate_env_runners_after_construction                                    True |
# | worker_cls                                                                   -1 |
# +---------------------------------------------------------------------------------+
# (DQN pid=1015) /usr/local/lib/python3.10/dist-packages/ray/rllib/connectors/agent/obs_preproc.py:37: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
# (DQN pid=1015)   self._preprocessor = get_preprocessor(obs_space)(
# (DQN pid=1015) 2024-05-10 21:12:34,820	WARNING replay_buffer.py:60 -- Estimated max memory usage for replay buffer is 5.08194 GB (30000.0 batches of size 1, 169398 bytes each), available system memory is 13.60945152 GB
# (DQN pid=1015) 2024-05-10 21:12:34,821	WARNING multi_agent_prioritized_replay_buffer.py:215 -- Adding batches with column `weights` to this buffer while providing weights as a call argument to the add method results in the column being overwritten.
# (DQN pid=1015) 2024-05-10 21:12:42,005	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 1 at 2024-05-10 21:12:42. Total running time: 20s
# +------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result           |
# +------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        413.5 |
# | env_runner_results/episode_return_mean                        75 |
# | num_env_steps_sampled_lifetime                              1002 |
# +------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:12:52. Total running time: 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         1            8.03594   1002         75                     90                     60                413.5                      2 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 2 at 2024-05-10 21:13:16. Total running time: 54s
# +------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result           |
# +------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        349.8 |
# | env_runner_results/episode_return_mean                        46 |
# | num_env_steps_sampled_lifetime                              2004 |
# +------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:13:22. Total running time: 1min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         2            42.2388   2004         46                     90                      0                349.8                      3 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 3 at 2024-05-10 21:13:50. Total running time: 1min 28s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        328.667 |
# | env_runner_results/episode_return_mean                     37.7778 |
# | num_env_steps_sampled_lifetime                                3006 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:13:52. Total running time: 1min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         3            76.2442   3006    37.7778                     90                      0              328.667                      4 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:14:22. Total running time: 2min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         3            76.2442   3006    37.7778                     90                      0              328.667                      4 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 4 at 2024-05-10 21:14:23. Total running time: 2min 1s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        346.455 |
# | env_runner_results/episode_return_mean                     50.9091 |
# | num_env_steps_sampled_lifetime                                4008 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:14:52. Total running time: 2min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         4            108.349   4008    50.9091                    140                      0              346.455                      2 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 5 at 2024-05-10 21:14:57. Total running time: 2min 35s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        344.214 |
# | env_runner_results/episode_return_mean                     51.4286 |
# | num_env_steps_sampled_lifetime                                5010 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:15:22. Total running time: 3min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         5            142.631   5010    51.4286                    140                      0              344.214                      3 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 6 at 2024-05-10 21:15:30. Total running time: 3min 8s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        345.765 |
# | env_runner_results/episode_return_mean                     54.1176 |
# | num_env_steps_sampled_lifetime                                6012 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:15:52. Total running time: 3min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         6            175.283   6012    54.1176                    140                      0              345.765                      3 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 7 at 2024-05-10 21:16:02. Total running time: 3min 40s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        351.684 |
# | env_runner_results/episode_return_mean                     56.8421 |
# | num_env_steps_sampled_lifetime                                7014 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:16:22. Total running time: 4min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         7            207.459   7014    56.8421                    140                      0              351.684                      2 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 8 at 2024-05-10 21:16:35. Total running time: 4min 13s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        373.238 |
# | env_runner_results/episode_return_mean                     56.1905 |
# | num_env_steps_sampled_lifetime                                8016 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:16:52. Total running time: 4min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         8            241.001   8016    56.1905                    140                      0              373.238                      2 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 9 at 2024-05-10 21:17:09. Total running time: 4min 47s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        380.957 |
# | env_runner_results/episode_return_mean                     54.7826 |
# | num_env_steps_sampled_lifetime                                9018 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:17:22. Total running time: 5min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)     ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING         9            274.641   9018    54.7826                    140                      0              380.957                      2 |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 10 at 2024-05-10 21:17:42. Total running time: 5min 20s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        380.769 |
# | env_runner_results/episode_return_mean                     60.7692 |
# | num_env_steps_sampled_lifetime                               10020 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:17:52. Total running time: 5min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING        10            307.043   10020    60.7692                    140                      0              380.769                      3 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 11 at 2024-05-10 21:18:16. Total running time: 5min 53s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        373.759 |
# | env_runner_results/episode_return_mean                     63.4483 |
# | num_env_steps_sampled_lifetime                               11022 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:18:22. Total running time: 6min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING        11            340.985   11022    63.4483                    140                      0              373.759                      3 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 12 at 2024-05-10 21:18:48. Total running time: 6min 26s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        368.094 |
# | env_runner_results/episode_return_mean                      65.625 |
# | num_env_steps_sampled_lifetime                               12024 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:18:52. Total running time: 6min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING        12            373.172   12024     65.625                    140                      0              368.094                      3 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 13 at 2024-05-10 21:19:20. Total running time: 6min 58s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        361.417 |
# | env_runner_results/episode_return_mean                     67.2222 |
# | num_env_steps_sampled_lifetime                               13026 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:19:22. Total running time: 7min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING        13            405.427   13026    67.2222                    140                      0              361.417                      4 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:19:52. Total running time: 7min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING        13            405.427   13026    67.2222                    140                      0              361.417                      4 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 14 at 2024-05-10 21:19:54. Total running time: 7min 32s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        357.308 |
# | env_runner_results/episode_return_mean                     68.2051 |
# | num_env_steps_sampled_lifetime                               14028 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:20:23. Total running time: 8min 0s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)      ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING        14            439.448   14028    68.2051                    140                      0              357.308                      3 |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 15 at 2024-05-10 21:20:28. Total running time: 8min 6s
# +--------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result             |
# +--------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        354.143 |
# | env_runner_results/episode_return_mean                     69.5238 |
# | num_env_steps_sampled_lifetime                               15030 |
# +--------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-10 21:20:53. Total running time: 8min 30s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       342            10956.9   342684        148                    220                     40                  596                      1 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 343 at 2024-05-11 00:16:01. Total running time: 3hr 3min 39s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        598.69 |
# | env_runner_results/episode_return_mean                      147.6 |
# | num_env_steps_sampled_lifetime                             343686 |
# +-------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-11 00:16:11. Total running time: 3hr 3min 49s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       343              10989   343686      147.6                    220                     40               598.69                      1 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 344 at 2024-05-11 00:16:32. Total running time: 3hr 4min 9s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        603.64 |
# | env_runner_results/episode_return_mean                      149.1 |
# | num_env_steps_sampled_lifetime                             344688 |
# +-------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-11 00:16:41. Total running time: 3hr 4min 19s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       344            11019.5   344688      149.1                    220                     40               603.64                      1 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 345 at 2024-05-11 00:17:01. Total running time: 3hr 4min 39s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        606.64 |
# | env_runner_results/episode_return_mean                      150.2 |
# | num_env_steps_sampled_lifetime                             345690 |
# +-------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-11 00:17:11. Total running time: 3hr 4min 49s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       345            11049.3   345690      150.2                    220                     40               606.64                      2 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 346 at 2024-05-11 00:17:33. Total running time: 3hr 5min 10s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        606.41 |
# | env_runner_results/episode_return_mean                        149 |
# | num_env_steps_sampled_lifetime                             346692 |
# +-------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-11 00:17:41. Total running time: 3hr 5min 19s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       346            11080.4   346692        149                    220                     40               606.41                      2 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 347 at 2024-05-11 00:18:05. Total running time: 3hr 5min 43s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        599.01 |
# | env_runner_results/episode_return_mean                      146.8 |
# | num_env_steps_sampled_lifetime                             347694 |
# +-------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-11 00:18:11. Total running time: 3hr 5min 49s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       347            11112.7   347694      146.8                    220                     40               599.01                      3 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 348 at 2024-05-11 00:18:35. Total running time: 3hr 6min 13s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        589.41 |
# | env_runner_results/episode_return_mean                      144.7 |
# | num_env_steps_sampled_lifetime                             348696 |
# +-------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-11 00:18:41. Total running time: 3hr 6min 19s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       348            11142.5   348696      144.7                    220                     40               589.41                      3 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 349 at 2024-05-11 00:19:05. Total running time: 3hr 6min 43s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        579.16 |
# | env_runner_results/episode_return_mean                      143.3 |
# | num_env_steps_sampled_lifetime                             349698 |
# +-------------------------------------------------------------------+
#
# Trial status: 1 RUNNING
# Current time: 2024-05-11 00:19:11. Total running time: 3hr 6min 49s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status       iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   RUNNING       349            11172.8   349698      143.3                    220                     40               579.16                      3 |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# 2024-05-11 00:19:35,809	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-05-11 00:19:35,841	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/FrostbiteModel' in 0.0558s.
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 finished iteration 350 at 2024-05-11 00:19:35. Total running time: 3hr 7min 13s
# +-------------------------------------------------------------------+
# | Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 result            |
# +-------------------------------------------------------------------+
# | env_runner_results/episode_len_mean                        570.45 |
# | env_runner_results/episode_return_mean                      140.3 |
# | num_env_steps_sampled_lifetime                             350700 |
# +-------------------------------------------------------------------+
#
# Trial DQN_FrostbiteDeterministic-v4_fdef7_00000 completed after 350 iterations at 2024-05-11 00:19:35. Total running time: 3hr 7min 13s
#
# Trial status: 1 TERMINATED
# Current time: 2024-05-11 00:19:35. Total running time: 3hr 7min 13s
# Logical resource usage: 1.0/2 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:T4)
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name                                  status         iter     total time (s)       ts     reward     episode_reward_max     episode_reward_min     episode_len_mean     episodes_this_iter |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | DQN_FrostbiteDeterministic-v4_fdef7_00000   TERMINATED      350            11202.9   350700      140.3                    220                     40               570.45                      3 |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
